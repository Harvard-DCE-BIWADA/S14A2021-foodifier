# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pathlib
import glob

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
data_dir = r'/mnt/c/Users/simon/Documents/GitHub/food-101/images'
data_dir = pathlib.Path(data_dir)
print(data_dir)
# Out:
# /mnt/c/Users/simon/Documents/GitHub/food-101/images

# %%
roses = list(data_dir.glob('apple_pie/*'))
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=308x512 at 0x7F0B8891DD30>
